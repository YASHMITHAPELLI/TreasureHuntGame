# %%
#Treasure Hunt Game using Python 3

def playagain():
    print("\n Do u want to play again (y or n)")
    answer=input(">").lower()
    if answer=='y':
        start()
    else:
        Game_over()  
def snake_room():
    print("\nthere is snake here.")
    print("\nBehind the snake is another door.")
    print("\nthe snake is having eggs!.")
    print("\nWhat would you do (1 or 2)")
    print("\n1)take the eggs!.")
    print("\n2)taunt the snake.")
    ansS=int(input(">"))
    if ansS==1:
        print("\nYou want eggs not the treasure!thats why the snake killed you.")
        print("\nGAME OVER")
        Game_over()
        playagain()
    else:
        treasure_room()
        
def treasure_room():
    print("\nYou are now in a room filled with diamonds!.")
    print("\nAnd theres a door too!.")
    print("What would you do (1 or 2)")
    print("1) take some diamonds and go through the door!.")
    print("2) just go through the door.")
    anss=int(input(">"))
    if anss==1:
        print("GAME OVER")
        Game_over()
        playagain()
    else:
        print("||||||||YAY YAY WIN||||||||")
        playagain()
          
def monster_room():
    print("Now you entered the room of monster!")
    print("The monster is sleeping!")
    print("\nBehind the monster, there is another door.what would you do?(1 or 2)")
    print("\n1)Go through the door silently.")
    print("\n2)Kill the monster and show your courage!!")
    ansA=int(input(">"))
    if ansA==1:
        treasure_room()
        
    else:
        print("The monster was hungery,he ate you!")
        print("\nGAME OVER")
        Game_over()
        playagain()       
    
def Game_over():
    exit()
def start():
    print("You are standing in a dark room")
    print("There is door to your left and right,Which one do you take?(l or r)")
    ans= input(">").lower()
    if ans=="l" :
        snake_room()
    else:
        monster_room()       
def main():
    start()      

main()
# Out:
# You are standing in a dark room
# There is door to your left and right,Which one do you take?(l or r)
# >l
#
# there is snake here.
#
# Behind the snake is another door.
#
# the snake is having eggs!.
#
# What would you do (1 or 2)
#
# 1)take the eggs!.
#
# 2)taunt the snake.
# >1
#
# You want eggs not the treasure!thats why the snake killed you.
#
# GAME OVER
#
#  Do u want to play again (y or n)
# >y
# You are standing in a dark room
# There is door to your left and right,Which one do you take?(l or r)
# >l
#
# there is snake here.
#
# Behind the snake is another door.
#
# the snake is having eggs!.
#
# What would you do (1 or 2)
#
# 1)take the eggs!.
#
# 2)taunt the snake.
# >2
#
# You are now in a room filled with diamonds!.
#
# And theres a door too!.
# What would you do (1 or 2)
# 1) take some diamonds and go through the door!.
# 2) just go through the door.
# >1
# GAME OVER
#
#  Do u want to play again (y or n)
# >y
# You are standing in a dark room
# ...
